# %%
import pandas as pd

# %%
import os
file_path = os.getcwd() + "\\dane\TPD_1000.csv"

# %%
tpd_top_1000 = pd.read_csv(file_path)

# %%
tpd_top_1000.head()
# Out:
#      RowId TypKarty  TxnKod   TxnData  TxnCzas  DataPrzetw  DCC  CTLS  PIN  \
# 0  1497431        M    2012  20180801    73143    20180801    0     1    1
# 1  1497435        M    2012  20180801   172557    20180801    0     0    1
# 2  1497436        M    2012  20180801    70751    20180801    0     1    1
# 3  1497437        M    2012  20180801   170654    20180801    0     1    1
# 4  1497443        M    2012  20180801   122720    20180801    0     1    1
#
#    CB       ...       Country                          anon_MID  \
# 0   0       ...            PL  8fef96ce980cba8ff8f08de425001e8b
# 1   0       ...            PL  c12e12f648fd0bb327385887a112031a
# 2   0       ...            PL  7c9797b73283de6f067270d0ccebaa3f
# 3   0       ...            PL  e467f14fb2b81847acf9a7b1a69c5061
# 4   0       ...            PL  b698920f6829768d3a6ff8b5ea95a667
#
#                         anon_POS_ID                      anon_NrKarty  \
# ...
